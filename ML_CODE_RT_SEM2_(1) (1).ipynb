# %% [markdown]
# Key Columns (Features)
#
# block_signed_at: Timestamp when the block was signed.
#
# block_height: Block number in the Ethereum blockchain.
#
# tx_hash: Unique transaction identifier.
#
# successful: Boolean (True/False) indicating transaction success.
#
# from_address / to_address: Sender and recipient Ethereum addresses.
#
# value: Transaction value in Wei (smallest unit of ETH).
#
# value_quote: Value of the transaction in USD.
#
# gas_offered / gas_spent / gas_price: Gas details for transaction fees.
#
# fees_paid: Total fees paid in Wei.
#
# gas_quote: Transaction fee in USD.
#
# Blockchain / Protocol: Specifies the blockchain (Ethereum) and protocol (Lido).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define file paths
import pandas as pd
file_paths = [
"/content/drive/MyDrive/RT 2 DATA/Aave_Transactions_Optimism.csv",
"/content/drive/MyDrive/RT 2 DATA/Aave_Transactions_Polygon.csv",
"/content/drive/MyDrive/RT 2 DATA/BalancerTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/Balancer_Transactions_Polygon.csv",
"/content/drive/MyDrive/RT 2 DATA/CompoundTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/Compound_Transactions_Polygon.csv",
"/content/drive/MyDrive/RT 2 DATA/Curve FinanceTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/Curve Finance_Transactions_Arbitrum.csv",
"/content/drive/MyDrive/RT 2 DATA/Curve Finance_Transactions_Polygon.csv",
"/content/drive/MyDrive/RT 2 DATA/LidoTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/Lido_Transactions_Arbitrum.csv",
"/content/drive/MyDrive/RT 2 DATA/Lido_Transactions_Optimism.csv",
"/content/drive/MyDrive/RT 2 DATA/Lido_Transactions_Polygon.csv",
"/content/drive/MyDrive/RT 2 DATA/MakerDAOTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/MakerDAO_Transactions_Avalanche.csv",
"/content/drive/MyDrive/RT 2 DATA/MakerDAO_Transactions_Polygon.csv",
"/content/drive/MyDrive/RT 2 DATA/Pangolin_Transactions_Avalanche.csv",
"/content/drive/MyDrive/RT 2 DATA/SushiSwapTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/SushiSwap_Transactions_Arbitrum.csv",
"/content/drive/MyDrive/RT 2 DATA/SushiSwap_Transactions_Avalanche.csv",
"/content/drive/MyDrive/RT 2 DATA/SushiSwap_Transactions_Fantom.csv",
"/content/drive/MyDrive/RT 2 DATA/SushiSwap_Transactions_Polygon.csv",
"/content/drive/MyDrive/RT 2 DATA/Trader Joe_Transactions_Avalanche.csv",
"/content/drive/MyDrive/RT 2 DATA/UniswapTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/Uniswap_Transactions_Arbitrum.csv",
"/content/drive/MyDrive/RT 2 DATA/Uniswap_Transactions_Avalanche.csv",
"/content/drive/MyDrive/RT 2 DATA/Uniswap_Transactions_Optimism.csv",
"/content/drive/MyDrive/RT 2 DATA/Yearn FinanceTransactionsEthereum.csv",
"/content/drive/MyDrive/RT 2 DATA/Yearn Finance_Transactions_Fantom.csv",
"/content/drive/MyDrive/RT 2 DATA/Yield Yak_Transactions_Avalanche.csv",
]

# Read and concatenate all datasets
df = [pd.read_csv(file) for file in file_paths]
df = pd.concat(df, ignore_index=True)

# Display the combined DataFrame
df
# Out:
#                   block_signed_at  block_height  \
# 0       2025-03-25 11:02:39+00:00     133650891
# 1       2025-03-25 11:00:15+00:00     133650819
# 2       2025-03-25 10:57:53+00:00     133650748
# 3       2025-03-25 10:55:49+00:00     133650686
# 4       2025-03-25 10:53:37+00:00     133650620
# ...                           ...           ...
# 120265  2025-03-14 08:27:11+00:00      58702901
# 120266  2025-03-13 23:07:50+00:00      58684648
# 120267  2025-03-13 17:54:26+00:00      58673760
# 120268  2025-03-13 16:30:22+00:00      58670798
# 120269  2025-03-13 13:51:43+00:00      58664863
#
#                                                block_hash  \
# 0       0xb6ad6d242df818eba3313db4e8e315804e7d49afac3b...
# 1       0x6f0f7f9b0ccef4d51ebbc761364d272342bee8e501b0...
# 2       0x888989143dfbacfd3f682a7241ba67d85596d28cbbfd...
# 3       0xee17474c4cb1b74df7811342673eed9af8ec64c6eec6...
# 4       0x6f5d2067a4bebacfe49f4c2c981cf264c2b5c74d8d5f...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120270 entries, 0 to 120269
# Data columns (total 26 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   block_signed_at     120270 non-null  object
#  1   block_height        120270 non-null  int64
#  2   block_hash          120270 non-null  object
#  3   tx_hash             120270 non-null  object
#  4   tx_offset           120270 non-null  int64
#  5   successful          120270 non-null  bool
#  6   miner_address       120270 non-null  object
#  7   from_address        120270 non-null  object
#  8   from_address_label  0 non-null       float64
#  9   to_address          119470 non-null  object
#  10  to_address_label    0 non-null       float64
#  11  value               120270 non-null  object
#  12  value_quote         120270 non-null  float64
#  13  pretty_value_quote  120270 non-null  object
#  14  gas_metadata        120270 non-null  object
# ...

# %%
df1 = df.drop(df[['from_address_label','to_address_label']],axis=1)

# %%
for col in df1.columns:
  print(f"Column '{col}': {df1[col].nunique()} unique values")
# Out:
# Column 'block_signed_at': 1311 unique values
# Column 'block_height': 1313 unique values
# Column 'block_hash': 1313 unique values
# Column 'tx_hash': 1548 unique values
# Column 'tx_offset': 220 unique values
# Column 'successful': 2 unique values
# Column 'miner_address': 37 unique values
# Column 'from_address': 802 unique values
# Column 'to_address': 361 unique values
# Column 'value': 229 unique values
# Column 'value_quote': 592 unique values
# Column 'pretty_value_quote': 319 unique values
# Column 'gas_metadata': 8 unique values
# Column 'gas_offered': 974 unique values
# Column 'gas_spent': 1150 unique values
# Column 'gas_price': 1119 unique values
# Column 'fees_paid': 1469 unique values
# Column 'gas_quote': 3824 unique values
# Column 'pretty_gas_quote': 305 unique values
# Column 'gas_quote_rate': 266 unique values
# Column 'explorers': 1548 unique values
# Column 'log_events': 1555 unique values
# Column 'Blockchain': 6 unique values
# ...

# %%
df1=df1.drop(df1[['Protocol']],axis=1)

# %%
df_unique = df.drop_duplicates(subset='tx_hash', keep='first')

# %%
df = df_unique
df
# Out:
#                   block_signed_at  block_height  \
# 0       2025-03-25 11:02:39+00:00     133650891
# 1       2025-03-25 11:00:15+00:00     133650819
# 2       2025-03-25 10:57:53+00:00     133650748
# 3       2025-03-25 10:55:49+00:00     133650686
# 4       2025-03-25 10:53:37+00:00     133650620
# ...                           ...           ...
# 118285  2025-03-14 08:27:11+00:00      58702901
# 118286  2025-03-13 23:07:50+00:00      58684648
# 118287  2025-03-13 17:54:26+00:00      58673760
# 118288  2025-03-13 16:30:22+00:00      58670798
# 118289  2025-03-13 13:51:43+00:00      58664863
#
#                                                block_hash  \
# 0       0xb6ad6d242df818eba3313db4e8e315804e7d49afac3b...
# 1       0x6f0f7f9b0ccef4d51ebbc761364d272342bee8e501b0...
# 2       0x888989143dfbacfd3f682a7241ba67d85596d28cbbfd...
# 3       0xee17474c4cb1b74df7811342673eed9af8ec64c6eec6...
# 4       0x6f5d2067a4bebacfe49f4c2c981cf264c2b5c74d8d5f...
# ...

# %%
from google.colab import files

df_unique.to_csv('combined_data.csv', index=False)  # Save without the index
files.download('combined_data.csv')

# %%
import pandas as pd
# df = pd.read_csv("/content/combined_data (1).csv")
df = pd.read_csv("/content/combined_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-e2ecc87fe3c8> in <cell line: 0>()
#       1 import pandas as pd
#       2 # df = pd.read_csv("/content/combined_data (1).csv")
# ----> 3 df = pd.read_csv("/content/combined_data.csv")
#
# ...

# %%
import pandas as pd

# Specify error handling and potentially different delimiter
df = pd.read_csv("/content/combined_data (1).csv", on_bad_lines='skip', delimiter=',')  # Or try sep='\t' if tab-separated

# Display the DataFrame to check the data
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-3d13871b4a60> in <cell line: 0>()
#       2
#       3 # Specify error handling and potentially different delimiter
# ----> 4 df = pd.read_csv("/content/combined_data (1).csv", on_bad_lines='skip', delimiter=',')  # Or try sep='\t' if tab-separated
#       5
#       6 # Display the DataFrame to check the data
#
# ...

# %%
df.nunique()
# Out:
# block_signed_at       1311
# block_height          1313
# block_hash            1313
# tx_hash               1548
# tx_offset              220
# successful               2
# miner_address           37
# from_address           802
# from_address_label       0
# to_address             361
# to_address_label         0
# value                  220
# value_quote            257
# pretty_value_quote     152
# gas_metadata             6
# gas_offered            974
# gas_spent             1150
# gas_price             1119
# fees_paid             1469
# gas_quote             1493
# pretty_gas_quote       273
# gas_quote_rate         251
# explorers             1548
# log_events            1506
# Blockchain               6
# Protocol                 1
# dtype: int64

# %%
# Drop unnecessary columns
df.drop(columns=['to_address_label', 'from_address_label'], inplace=True)

# Verify the changes
print(df.head())
# Out:
#              block_signed_at  block_height  \
# 0  2025-03-25 11:02:39+00:00     133650891
# 1  2025-03-25 11:00:15+00:00     133650819
# 2  2025-03-25 10:57:53+00:00     133650748
# 3  2025-03-25 10:55:49+00:00     133650686
# 4  2025-03-25 10:53:37+00:00     133650620
#
#                                           block_hash  \
# 0  0xb6ad6d242df818eba3313db4e8e315804e7d49afac3b...
# 1  0x6f0f7f9b0ccef4d51ebbc761364d272342bee8e501b0...
# 2  0x888989143dfbacfd3f682a7241ba67d85596d28cbbfd...
# 3  0xee17474c4cb1b74df7811342673eed9af8ec64c6eec6...
# 4  0x6f5d2067a4bebacfe49f4c2c981cf264c2b5c74d8d5f...
#
#                                              tx_hash  tx_offset  successful  \
# 0  0xfac75e7abbf1f6bb59869419051ef3201082ebfda9f5...         33        True
# 1  0x9501df5009cab76a6efc5d8171aec2efca6425a4d9c5...          5        True
# 2  0x5ae62f8b9f32f5d08c2776877eb5f556ee65938ccbbb...          5        True
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# List of categorical columns to encode
categorical_cols = ['from_address', 'to_address', 'block_hash', 'tx_hash', 'miner_address']

# Apply Label Encoding
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Store encoders for future use

# Display the first few rows after encoding
print(df.head())
# Out:
#              block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 0  2025-03-25 11:02:39+00:00     133650891        1006     1508         33
# 1  2025-03-25 11:00:15+00:00     133650819         630      919          5
# 2  2025-03-25 10:57:53+00:00     133650748         773      534          5
# 3  2025-03-25 10:55:49+00:00     133650686        1240      146          8
# 4  2025-03-25 10:53:37+00:00     133650620         633     1373          8
#
#    successful  miner_address  from_address  to_address          value  ...  \
# 0        True             13           726         319   812502146784  ...
# 1        True             13           148         319  1352278970644  ...
# 2        True             13           509         319  2711564532116  ...
# 3        True             13           503         319  1701037562169  ...
# 4        True             13           370         319  2086029514957  ...
#
# ...

# %%
df
# Out:
#                 block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 0     2025-03-25 11:02:39+00:00     133650891        1006     1508         33
# 1     2025-03-25 11:00:15+00:00     133650819         630      919          5
# 2     2025-03-25 10:57:53+00:00     133650748         773      534          5
# 3     2025-03-25 10:55:49+00:00     133650686        1240      146          8
# 4     2025-03-25 10:53:37+00:00     133650620         633     1373          8
# ...                         ...           ...         ...      ...        ...
# 1543  2025-03-14 08:27:11+00:00      58702901        1029      431          2
# 1544  2025-03-13 23:07:50+00:00      58684648         571      422          3
# 1545  2025-03-13 17:54:26+00:00      58673760         452      818          7
# 1546  2025-03-13 16:30:22+00:00      58670798         796     1251         13
# 1547  2025-03-13 13:51:43+00:00      58664863         333     1278         25
#
# ...

# %%
# Check missing values
print(df.isnull().sum())

# Option 1: Fill missing values with 0 or mean/median (depends on the feature)
df = df.fillna(0)
df.isnull().sum()
# Out:
# block_signed_at        0
# block_height           0
# block_hash             0
# tx_hash                0
# tx_offset              0
# successful             0
# miner_address          0
# from_address           0
# to_address             0
# value                  0
# value_quote            0
# pretty_value_quote     0
# gas_metadata           0
# gas_offered            0
# gas_spent              0
# gas_price              0
# fees_paid              0
# gas_quote              0
# pretty_gas_quote       0
# gas_quote_rate         0
# explorers              0
# log_events            42
# Blockchain             0
# Protocol               0
# dtype: int64
# block_signed_at       0
# block_height          0
# block_hash            0
# tx_hash               0
# tx_offset             0
# successful            0
# miner_address         0
# from_address          0
# to_address            0
# value                 0
# value_quote           0
# pretty_value_quote    0
# ...

# %%
df['block_signed_at'] = pd.to_datetime(df['block_signed_at'])

# %%
df['hour'] = df['block_signed_at'].dt.hour
df['day'] = df['block_signed_at'].dt.day
df['month'] = df['block_signed_at'].dt.month
df['year'] = df['block_signed_at'].dt.year

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_columns = ['value', 'gas_spent', 'gas_price', 'fees_paid']
df[scaled_columns] = scaler.fit_transform(df[scaled_columns])

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

# Load the data (assuming df is already preprocessed)

# %%
# Selecting relevant features for fraud detection
features = ['value', 'gas_spent', 'gas_price', 'fees_paid', 'hour', 'day', 'month', 'year']
X = df[features]

# %%
# Train Isolation Forest Model
iso_forest = IsolationForest(n_estimators=100, contamination=0.05, random_state=42)
df['fraud_score'] = iso_forest.fit_predict(X)

# %%
# Mark fraud transactions
df['is_fraud'] = df['fraud_score'].apply(lambda x: 1 if x == -1 else 0)

# Display fraud transactions
fraudulent_transactions = df[df['is_fraud'] == 1]
print(fraudulent_transactions)
# Out:
#                block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 59   2025-03-22 06:47:23+00:00      69351263        1141     1494          8
# 65   2025-03-22 06:41:29+00:00      69351096         639      446          2
# 67   2025-03-22 06:40:35+00:00      69351071         649      234         47
# 68   2025-03-22 06:40:19+00:00      69351063         475     1468          3
# 127  2025-03-22 07:18:50+00:00      69352148         499     1248          2
# ...                        ...           ...         ...      ...        ...
# 1004 2018-12-29 18:35:52+00:00       6975375         802      232          7
# 1005 2018-11-15 03:36:22+00:00       6706732        1020      543         57
# 1006 2018-09-27 20:32:50+00:00       6411054        1310      702         34
# 1309 2025-03-14 21:04:09+00:00      58728602         969      140          5
# 1310 2025-03-14 20:42:33+00:00      58727907         957      132          0
#
# ...

# %%
df
# Out:
#                block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 0    2025-03-25 11:02:39+00:00     133650891        1006     1508         33
# 1    2025-03-25 11:00:15+00:00     133650819         630      919          5
# 2    2025-03-25 10:57:53+00:00     133650748         773      534          5
# 3    2025-03-25 10:55:49+00:00     133650686        1240      146          8
# 4    2025-03-25 10:53:37+00:00     133650620         633     1373          8
# ...                        ...           ...         ...      ...        ...
# 1543 2025-03-14 08:27:11+00:00      58702901        1029      431          2
# 1544 2025-03-13 23:07:50+00:00      58684648         571      422          3
# 1545 2025-03-13 17:54:26+00:00      58673760         452      818          7
# 1546 2025-03-13 16:30:22+00:00      58670798         796     1251         13
# 1547 2025-03-13 13:51:43+00:00      58664863         333     1278         25
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x=df['fraud_score'])
plt.title("Distribution of Normal vs Fraudulent Transactions")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['value'], y=df['gas_spent'], hue=df['is_fraud'], palette=['blue', 'red'])
plt.xlabel("Transaction Value")
plt.ylabel("Gas Spent")
plt.title("Fraud Detection using Isolation Forest")
plt.show()

# %%
df[df['fraud_score'] == -1]
# Out:
#                block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 59   2025-03-22 06:47:23+00:00      69351263        1141     1494          8
# 65   2025-03-22 06:41:29+00:00      69351096         639      446          2
# 67   2025-03-22 06:40:35+00:00      69351071         649      234         47
# 68   2025-03-22 06:40:19+00:00      69351063         475     1468          3
# 127  2025-03-22 07:18:50+00:00      69352148         499     1248          2
# ...                        ...           ...         ...      ...        ...
# 1004 2018-12-29 18:35:52+00:00       6975375         802      232          7
# 1005 2018-11-15 03:36:22+00:00       6706732        1020      543         57
# 1006 2018-09-27 20:32:50+00:00       6411054        1310      702         34
# 1309 2025-03-14 21:04:09+00:00      58728602         969      140          5
# 1310 2025-03-14 20:42:33+00:00      58727907         957      132          0
#
# ...

# %%
# Code to analyze fraudulent transactions

# Filter for fraudulent transactions
fraudulent_transactions = df[df['fraud_score'] == -1]

# Display summary statistics for fraudulent transactions
print(fraudulent_transactions.describe())

# Check the most common fraudulent miner addresses
print(fraudulent_transactions['miner_address'].value_counts().head(10))

# Check the most common fraudulent from/to addresses
print(fraudulent_transactions['from_address'].value_counts().head(10))
print(fraudulent_transactions['to_address'].value_counts().head(10))
# Out:
#        block_height   block_hash      tx_hash   tx_offset  miner_address  \
# count  7.800000e+01    78.000000    78.000000   78.000000      78.000000
# mean   4.273047e+07   744.589744   748.846154   61.320513       9.320513
# std    3.055910e+07   323.671689   478.094244   62.719639      11.943040
# min    5.250710e+06    99.000000    61.000000    0.000000       0.000000
# 25%    1.640644e+07   494.250000   268.750000   16.750000       0.000000
# 50%    4.887061e+07   710.500000   707.500000   45.000000       2.000000
# 75%    6.232578e+07  1012.000000  1172.500000   89.750000      16.500000
# max    1.972093e+08  1310.000000  1533.000000  312.000000      36.000000
#
#        from_address  to_address      value  value_quote   gas_offered  ...  \
# count     78.000000   78.000000  78.000000    78.000000  7.800000e+01  ...
# mean     466.564103  206.833333   0.660505   262.102203  2.269448e+06  ...
# std      218.836094   93.771402   4.251878  1585.229798  4.947332e+06  ...
# ...

# %% [markdown]
# Interpretation of the Output:
# This output provides insights into fraudulent transactions detected using the Isolation Forest algorithm.
#
# 1️⃣ Statistical Summary of Key Columns
# Gas Price, Fees Paid, Gas Quote Rate, Hour, Day, Month, Year
#
# Mean, Min, Max, and Quartiles help us understand the transaction distribution.
#
# Example: The gas_price has a mean of 1.513439, with a max value of 22.177083, indicating some high outliers.
#
# The year column shows values from 2020 to 2025, meaning transactions span multiple years.
#
# 2️⃣ Fraud Detection Results
# Fraud Score (fraud_score column)
#
# -1 → Indicates fraudulent transactions
#
# 1 → Indicates legitimate transactions
#
# The dataset has both fraudulent and normal transactions, with more -1 values suggesting a good detection rate.
#
# Is Fraud (is_fraud column)
#
# It mirrors the fraud score (1 or -1), confirming which transactions were flagged as fraudulent.
#
# 3️⃣ Frequent Addresses in Fraudulent Transactions
# Miner Address Analysis
#
# The miner address 0 appears 35 times, indicating it might be involved in fraudulent transactions.
#
# Other miners (e.g., 5, 24, 10) have smaller occurrences.
#
# From Address (Senders of Transactions)
#
# Address 565 appears 4 times, meaning it has multiple flagged transactions.
#
# Other addresses (582, 158, 738) also appear multiple times.
#
# To Address (Receivers of Transactions)
#
# Address 205 appears 13 times, making it a potential recipient of fraudulent funds.
#
# Other addresses (160, 341, 365) appear frequently as well.
#
# Key Takeaways
# ✅ Fraudulent transactions are detected (-1 fraud scores).
# ✅ Certain miner, sender, and recipient addresses appear frequently in fraud cases.
# ✅ Gas price and fees show some outliers, which could indicate suspicious activity.
#
# Next Steps
# 1️⃣ Investigate top fraud-prone addresses (e.g., miner_address=0, from_address=565, to_address=205).
# 2️⃣ Visualize fraud trends (e.g., how fraud changes over years, months, or gas prices).
# 3️⃣ Compare with Local Outlier Factor (LOF) or Deep Learning methods for better accuracy.

# %%
# FOR Local Outlier Factor (LOF)

df1= df

df1
# Out:
#                block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 0    2025-03-25 11:02:39+00:00     133650891        1006     1508         33
# 1    2025-03-25 11:00:15+00:00     133650819         630      919          5
# 2    2025-03-25 10:57:53+00:00     133650748         773      534          5
# 3    2025-03-25 10:55:49+00:00     133650686        1240      146          8
# 4    2025-03-25 10:53:37+00:00     133650620         633     1373          8
# ...                        ...           ...         ...      ...        ...
# 1543 2025-03-14 08:27:11+00:00      58702901        1029      431          2
# 1544 2025-03-13 23:07:50+00:00      58684648         571      422          3
# 1545 2025-03-13 17:54:26+00:00      58673760         452      818          7
# 1546 2025-03-13 16:30:22+00:00      58670798         796     1251         13
# 1547 2025-03-13 13:51:43+00:00      58664863         333     1278         25
#
# ...

# %%
#CONSIDERING SAME FEATURES FOR FAIR COMPARISON

from sklearn.neighbors import LocalOutlierFactor
import numpy as np

# Define the same features used for Isolation Forest
features = ['value', 'gas_spent', 'gas_price', 'fees_paid', 'hour', 'day', 'month', 'year']

# Drop fraud_score if it exists in df1
df1 = df1.drop(columns=['fraud_score','is_fraud'], errors='ignore')

# Apply Local Outlier Factor (LOF) using the same features
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.05)
df1['lof_score'] = lof.fit_predict(df1[features])

# Count occurrences of fraud (-1) and normal (1) cases
print(df1['lof_score'].value_counts())
# Out:
# lof_score
#  1    1470
# -1      78
# Name: count, dtype: int64

# %%
df1
# Out:
#                block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 0    2025-03-25 11:02:39+00:00     133650891        1006     1508         33
# 1    2025-03-25 11:00:15+00:00     133650819         630      919          5
# 2    2025-03-25 10:57:53+00:00     133650748         773      534          5
# 3    2025-03-25 10:55:49+00:00     133650686        1240      146          8
# 4    2025-03-25 10:53:37+00:00     133650620         633     1373          8
# ...                        ...           ...         ...      ...        ...
# 1543 2025-03-14 08:27:11+00:00      58702901        1029      431          2
# 1544 2025-03-13 23:07:50+00:00      58684648         571      422          3
# 1545 2025-03-13 17:54:26+00:00      58673760         452      818          7
# 1546 2025-03-13 16:30:22+00:00      58670798         796     1251         13
# 1547 2025-03-13 13:51:43+00:00      58664863         333     1278         25
#
# ...

# %%
# Compare with Local Outlier Factor (LOF)
# LOF considers local density instead of just isolation. Let's compare results.

from sklearn.neighbors import LocalOutlierFactor

# Define contamination level (start small and adjust as needed)
contamination_level = 0.05

# Drop fraud_score if it exists
df1 = df1.drop(columns=['fraud_score','is_fraud'], errors='ignore')

# Apply Local Outlier Factor (LOF) but EXCLUDE the block_signed_at column

# Select only numerical features for LOF
numerical_features = df1.select_dtypes(include=np.number).columns.tolist()
# Remove 'lof_score' if it exists
numerical_features = [f for f in numerical_features if f != 'lof_score']

lof = LocalOutlierFactor(n_neighbors=20, contamination=contamination_level)
df1['lof_score'] = lof.fit_predict(df1[numerical_features])

# Count occurrences of fraud (-1) and normal (1) cases
print(df1['lof_score'].value_counts())
# Out:
# lof_score
#  1    1470
# -1      78
# Name: count, dtype: int64

# %%
df1
# Out:
#                block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 0    2025-03-25 11:02:39+00:00     133650891        1006     1508         33
# 1    2025-03-25 11:00:15+00:00     133650819         630      919          5
# 2    2025-03-25 10:57:53+00:00     133650748         773      534          5
# 3    2025-03-25 10:55:49+00:00     133650686        1240      146          8
# 4    2025-03-25 10:53:37+00:00     133650620         633     1373          8
# ...                        ...           ...         ...      ...        ...
# 1543 2025-03-14 08:27:11+00:00      58702901        1029      431          2
# 1544 2025-03-13 23:07:50+00:00      58684648         571      422          3
# 1545 2025-03-13 17:54:26+00:00      58673760         452      818          7
# 1546 2025-03-13 16:30:22+00:00      58670798         796     1251         13
# 1547 2025-03-13 13:51:43+00:00      58664863         333     1278         25
#
# ...

# %% [markdown]
# ***To compare the Isolation Forest and Local Outlier Factor (LOF) fraud predictions, follow these steps:***

# %% [markdown]
# **Step 1: Ensure Both Models' Predictions Exist
# Before comparison, check if both fraud_score (from Isolation Forest) and lof_score (from LOF) exist in your dataset. If fraud_score was removed earlier, rerun Isolation Forest:**

# %%
from sklearn.ensemble import IsolationForest

# Define contamination level (same as LOF)
contamination_level = 0.05

# Apply Isolation Forest again
iso_forest = IsolationForest(contamination=contamination_level, random_state=42)
df['fraud_score'] = iso_forest.fit_predict(df.drop(columns=['lof_score'], errors='ignore'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-1ae191a492a2> in <cell line: 0>()
#       6 # Apply Isolation Forest again
#       7 iso_forest = IsolationForest(contamination=contamination_level, random_state=42)
# ----> 8 df['fraud_score'] = iso_forest.fit_predict(df1.drop(columns=['lof_score'], errors='ignore'))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_predict(self, X, y, **kwargs)
#    1144
#    1145         # override for transductive outlier detectors like LocalOulierFactor
# -> 1146         return self.fit(X, **kwargs).predict(X)
#    1147
#    1148
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# ...

# %% [markdown]
# **Compare Fraud Predictions
# Now, check how many transactions both models agree or disagree on.**

# %%
# Create a comparison column in df
df['fraud_agreement'] = df['fraud_score'] == df1['lof_score']

# Count how many transactions both models agree on
agreement_counts = df['fraud_agreement'].value_counts()
print("Agreement Counts:\n", agreement_counts)
# Out:
# Agreement Counts:
#  fraud_agreement
# True     1404
# False     144
# Name: count, dtype: int64

# %% [markdown]
# **Breakdown of Fraud Overlaps
# We check how many transactions were flagged by both models as fraud (-1).**

# %%
import pandas as pd

# Count the overlap cases
fraud_overlap = df[(df['fraud_score'] == -1) & (df1['lof_score'] == -1)]
iso_only = df[(df['fraud_score'] == -1) & (df1['lof_score'] == 1)]
lof_only = df[(df['fraud_score'] == 1) & (df1['lof_score'] == -1)]

# Print the number of fraud cases detected by both and individually
print(f"Fraud flagged by both: {len(fraud_overlap)}")
print(f"Fraud flagged only by Isolation Forest: {len(iso_only)}")
print(f"Fraud flagged only by LOF: {len(lof_only)}")
# Out:
# Fraud flagged by both: 6
# Fraud flagged only by Isolation Forest: 72
# Fraud flagged only by LOF: 72

# %% [markdown]
# **Look for patterns:
# Did one model detect small transactions, while the other flagged high-value ones?
# Did they react differently to certain addresses or gas fees?
# Is one model more sensitive than the other**

# %% [markdown]
# Interpretation of Results
# Your results break down like this:
#
# ✅ Transactions where both models agree (1416 cases)
# ❌ Transactions where models disagree (132 cases)
# 🔍 Fraud detection breakdown:
#
# Both models flagged fraud: 12 cases → Strong fraud indicators ✅
#
# Only Isolation Forest flagged fraud: 66 cases
#
# Only LOF flagged fraud: 66 cases

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you already have these DataFrames
# iso_only_fraud and lof_only_fraud

# Compare key features
key_features = ["value", "gas_spent", "from_address", "to_address", "block_signed_at"]

# Summary statistics for Isolation Forest and LOF fraud cases
print("Isolation Forest Only Fraud Cases Summary:")
print(iso_only[key_features].describe())

print("\nLOF Only Fraud Cases Summary:")
print(lof_only[key_features].describe())

# Visualizing the difference in 'value' and 'gas_spent'
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(iso_only["value"], bins=30, color='blue', kde=True, ax=axes[0])
sns.histplot(lof_only["value"], bins=30, color='orange', kde=True, ax=axes[0])
axes[0].set_title("Distribution of Transaction Value")
axes[0].legend(["Isolation Forest", "LOF"])

sns.histplot(iso_only["gas_spent"], bins=30, color='blue', kde=True, ax=axes[1])
sns.histplot(lof_only["gas_spent"], bins=30, color='orange', kde=True, ax=axes[1])
axes[1].set_title("Distribution of Gas Spent")
axes[1].legend(["Isolation Forest", "LOF"])

plt.tight_layout()
plt.show()
# Out:
# Isolation Forest Only Fraud Cases Summary:
#            value  gas_spent  from_address  to_address
# count  72.000000  72.000000     72.000000   72.000000
# mean   -0.015367   0.644443    465.069444  214.652778
# std     0.577056   3.030316    220.129688   93.405546
# min    -0.083544  -0.512367     45.000000   20.000000
# 25%    -0.083544  -0.495123    281.500000  139.500000
# 50%    -0.083544  -0.226113    497.500000  244.000000
# 75%    -0.083544   0.343478    666.000000  281.500000
# max     4.813103  20.151680    791.000000  361.000000
#
# LOF Only Fraud Cases Summary:
#            value  gas_spent  from_address  to_address
# count  72.000000  72.000000     72.000000   72.000000
# mean    0.008378  -0.248275    413.680556  162.250000
# std     0.312994   0.643824    247.807503  123.385089
# min    -0.083544  -0.512367     29.000000   34.000000
# 25%    -0.083544  -0.459034    195.500000   34.000000
# 50%    -0.083544  -0.437959    381.500000  125.000000
# ...

# %% [markdown]
# INterpretation with respect to the above content
#
# ChatGPT said:
# Interpretation of the Results:
# 1. Statistical Comparison of Fraud Cases (Isolation Forest vs. LOF)
# Transaction Value (value):
#
# Isolation Forest: The median and interquartile range (IQR) suggest that most flagged transactions have negative values concentrated around -0.08.
#
# LOF: The median is the same (-0.08), but LOF detects some outliers, including a maximum value of 1.49, which Isolation Forest misses.
#
# Insight: LOF seems to detect higher-value fraud cases, while Isolation Forest may be more conservative, capturing lower-value fraud.
#
# Gas Spent (gas_spent):
#
# Isolation Forest: Mean gas spent is 3.04, with a max of 20.15.
#
# LOF: Mean gas spent is 0.64, and the max is 3.98.
#
# Insight: Isolation Forest tends to flag fraud cases where gas usage is significantly higher, whereas LOF primarily detects anomalies in transactions with lower gas usage.
#
# Addresses (from_address, to_address):
#
# The means of from_address and to_address vary between models.
#
# Insight: Isolation Forest and LOF might be flagging fraud in different groups of senders and receivers.
#
# 2. Visual Analysis (Histograms)
# Transaction Value Distribution:
#
# The histogram shows high overlap between Isolation Forest and LOF in low-value transactions.
#
# LOF catches a few higher-value frauds that Isolation Forest misses.
#
# Insight: LOF may be detecting more localized anomalies, while Isolation Forest works better on extreme outliers.
#
# Gas Spent Distribution:
#
# Isolation Forest tends to flag cases with higher gas usage, while LOF detects low-gas fraud.
#
# Insight: This suggests a possible dual fraud strategy—one with low gas to avoid detection, and another with high gas to rush transactions.

# %% [markdown]
# AUTOENCODER

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.preprocessing import MinMaxScaler

# Preprocessing
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Autoencoder Model
input_dim = X_scaled.shape[1]
input_layer = Input(shape=(input_dim,))
encoded = Dense(16, activation='relu')(input_layer)
encoded = Dense(8, activation='relu')(encoded)
decoded = Dense(16, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Train on normal transactions
autoencoder.fit(X_scaled, X_scaled, epochs=50, batch_size=32, shuffle=True)

# Compute reconstruction error (higher error = possible fraud)
reconstructions = autoencoder.predict(X_scaled)
mse = np.mean(np.abs(X_scaled - reconstructions), axis=1)

# Set threshold for fraud detection
threshold = np.percentile(mse, 95)
fraud_flags = mse > threshold
# Out:
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1598
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0842
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0314
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0148
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035
# Epoch 15/50
# ...

# %% [markdown]
# **Analyze Discrepancies
# For transactions that only one model flagged as fraud, check differences in their attributes:**

# %%
# View fraud cases flagged only by Isolation Forest
print("Fraud detected only by Isolation Forest:")
print(iso_only.head())

# View fraud cases flagged only by LOF
print("\nFraud detected only by LOF:")
print(lof_only.head())
# Out:
# Fraud detected only by Isolation Forest:
#               block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 59  2025-03-22 06:47:23+00:00      69351263        1141     1494          8
# 65  2025-03-22 06:41:29+00:00      69351096         639      446          2
# 67  2025-03-22 06:40:35+00:00      69351071         649      234         47
# 68  2025-03-22 06:40:19+00:00      69351063         475     1468          3
# 127 2025-03-22 07:18:50+00:00      69352148         499     1248          2
#
#      successful  miner_address  from_address  to_address     value  ...  \
# 59         True              0           340         310 -0.083544  ...
# 65         True              0           340         310 -0.083544  ...
# 67         True              0           274          61  4.813103  ...
# 68         True              0           340         310 -0.083544  ...
# 127       False              0           531         189 -0.083544  ...
#
# ...

# %% [markdown]
# **Next Steps 🚀
# ✅ Investigate the 12 fraud cases flagged by both models – What patterns do they share?
# ✅ Analyze the 132 mismatched cases – Why did one model flag them while the other didn't?
# ✅ Visualize Key Features – Look at distributions of fraud vs. normal transactions.**

# %%
# Step 1: Investigate Fraud Cases Flagged by Both Models
# We'll filter the dataset to examine the 12 transactions flagged as fraud by both Isolation Forest & LOF.

#  Code to Extract Common Fraud Cases


# Find frauds flagged by both models
both_fraud = df[(df['fraud_score'] == -1) & (df1['lof_score'] == -1)]

# Display key statistics
print("🔹 Shared Fraud Cases Summary:")
print(both_fraud.describe())

# Display the first few rows of these flagged frauds
both_fraud.head()
# Out:
# 🔹 Shared Fraud Cases Summary:
#        block_height   block_hash      tx_hash   tx_offset  miner_address  \
# count  1.200000e+01    12.000000    12.000000   12.000000      12.000000
# mean   7.711289e+07   603.666667   716.000000   34.833333      12.750000
# std    4.421634e+07   276.047207   369.200857   45.085441      13.942251
# min    3.674175e+07   247.000000    61.000000    1.000000       0.000000
# 25%    5.292778e+07   406.500000   550.000000    1.750000       0.000000
# 50%    6.030582e+07   557.500000   707.500000   20.000000       6.500000
# 75%    9.330507e+07   629.250000   887.000000   54.500000      28.000000
# max    1.972093e+08  1159.000000  1416.000000  153.000000      28.000000
#
#        from_address  to_address         value  value_quote   gas_offered  ...  \
# count     12.000000   12.000000  1.200000e+01    12.000000  1.200000e+01  ...
# mean     499.833333  252.500000 -8.354342e-02     0.011801  5.416788e+06  ...
# ...

# %%
# Code to Analyze Mismatched Cases

# Fraud detected by Isolation Forest but not LOF
iso_only_fraud = df[(df['fraud_score'] == -1) & (df1['lof_score'] == 1)]

# Fraud detected by LOF but not Isolation Forest
lof_only_fraud = df[(df['fraud_score'] == 1) & (df1['lof_score'] == -1)]

print(f"🔹 Fraud flagged only by Isolation Forest: {len(iso_only_fraud)}")
print(f"🔹 Fraud flagged only by LOF: {len(lof_only_fraud)}")

# Show sample cases
iso_only_fraud.head()
# Out:
# 🔹 Fraud flagged only by Isolation Forest: 66
# 🔹 Fraud flagged only by LOF: 66
#               block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 59  2025-03-22 06:47:23+00:00      69351263        1141     1494          8
# 65  2025-03-22 06:41:29+00:00      69351096         639      446          2
# 67  2025-03-22 06:40:35+00:00      69351071         649      234         47
# 68  2025-03-22 06:40:19+00:00      69351063         475     1468          3
# 127 2025-03-22 07:18:50+00:00      69352148         499     1248          2
#
#      successful  miner_address  from_address  to_address     value  ...  \
# 59         True              0           340         310 -0.083544  ...
# 65         True              0           340         310 -0.083544  ...
# 67         True              0           274          61  4.813103  ...
# 68         True              0           340         310 -0.083544  ...
# ...

# %%
lof_only_fraud.head()
# Out:
#               block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 129 2025-03-22 07:18:42+00:00      69352144         443     1511        190
# 263 2025-03-18 11:20:00+00:00      69197569         450     1545         71
# 288 2024-08-22 02:14:49+00:00      60883500         698     1176         48
# 289 2024-08-16 05:45:23+00:00      60648259         223     1092         34
# 290 2024-08-16 05:45:09+00:00      60648253        1294       41         43
#
#      successful  miner_address  from_address  to_address     value  ...  \
# 129        True              0           531         272 -0.083544  ...
# 263        True              0           146         154 -0.083544  ...
# 288        True              0           558         208 -0.083544  ...
# 289        True              0           558         171 -0.083544  ...
# 290        True              0           558         171 -0.083544  ...
#
# ...

# %%
df
# Out:
#                block_signed_at  block_height  block_hash  tx_hash  tx_offset  \
# 0    2025-03-25 11:02:39+00:00     133650891        1006     1508         33
# 1    2025-03-25 11:00:15+00:00     133650819         630      919          5
# 2    2025-03-25 10:57:53+00:00     133650748         773      534          5
# 3    2025-03-25 10:55:49+00:00     133650686        1240      146          8
# 4    2025-03-25 10:53:37+00:00     133650620         633     1373          8
# ...                        ...           ...         ...      ...        ...
# 1543 2025-03-14 08:27:11+00:00      58702901        1029      431          2
# 1544 2025-03-13 23:07:50+00:00      58684648         571      422          3
# 1545 2025-03-13 17:54:26+00:00      58673760         452      818          7
# 1546 2025-03-13 16:30:22+00:00      58670798         796     1251         13
# 1547 2025-03-13 13:51:43+00:00      58664863         333     1278         25
#
# ...

# %% [markdown]
# The first table (iso_only_fraud) contains transactions flagged as fraud by Isolation Forest but not LOF.
#
# The second table (lof_only_fraud) contains transactions flagged as fraud by LOF but not Isolation Forest.
#
# Since these rows were flagged as fraud by only one model, fraud_agreement is False because the models do not agree on these transactions.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of numerical columns to visualize
features = ['gas_spent', 'fees_paid', 'gas_price', 'gas_quote']

for feature in features:
    plt.figure(figsize=(8, 4))

    # KDE plot for fraud vs. normal transactions
    sns.kdeplot(df[df['fraud_score'] == -1][feature], label='Fraud (Isolation Forest)', fill=True, alpha=0.4)
    sns.kdeplot(df[df1['lof_score'] == -1][feature], label='Fraud (LOF)', fill=True, alpha=0.4)
    sns.kdeplot(df[(df['fraud_score'] == 1) & (df1['lof_score'] == 1)][feature], label='Normal Transactions', fill=True, alpha=0.4)

    plt.title(f'Distribution of {feature} - Fraud vs Normal')
    plt.legend()
    plt.show()

# %% [markdown]
# Interpretation of the Distribution of gas_spent (Fraud vs. Normal Transactions)
# Normal Transactions (Green)
#
# The majority of normal transactions have very low gas_spent, forming a sharp peak close to zero.
#
# The distribution is highly concentrated, indicating that most legitimate transactions use minimal gas.
#
# Fraudulent Transactions (Isolation Forest - Blue & LOF - Orange)
#
# Both fraud detection models (Isolation Forest & LOF) flag transactions with a slightly wider distribution of gas_spent.
#
# Fraudulent transactions tend to have a broader range than normal transactions.
#
# Some fraudulent transactions show a slight rightward tail, meaning certain fraud cases involve higher gas_spent compared to normal transactions.
#
# Overlap Between Models
#
# The blue (Isolation Forest) and orange (LOF) distributions overlap significantly, meaning both models are detecting similar transactions as fraud.
#
# However, there are slight variations, suggesting that each model flags unique transactions.
#
# Key Insights
# Fraudulent transactions appear to have a more varied gas_spent compared to normal transactions.
#
# Some fraud cases may involve higher gas fees, potentially indicating fraudulent behaviors like gas price manipulation.
#
# Further analysis should check if high gas spending is a strong fraud indicator or if additional factors contribute to detection.

# %%
data =pd.read_csv("/content/result.csv")

# %%
data
# Out:
#                                                   id   timestamp  \
# 0  0xea6d13eb2e9ee57397a7e11fc809eb1b7dd0e648fa1f...  1742934769
# 1  0xd0c79e92f86a971d6d4ff7604c030eb82a7eb85803a1...  1742934769
# 2  0xc8c1403755684966fb5d9cae2d7faa3ed221c642ec05...  1742934769
# 3  0xc3f4a0884c713e745f4ffe71d9ef6e2a3aefb7b9c84b...  1742934769
# 4  0x956157768a793c13a44b7ef92e71241d8eba09d076b7...  1742934769
#
#     amountInUSD  amountOutUSD  \
# 0  3.050554e+01  3.040057e+01
# 1  1.152279e-09  1.140756e-09
# 2  1.152279e-09  0.000000e+00
# 3  1.420116e+01  1.405769e+01
# 4  3.522605e+01  3.522252e+01
#
#                                                 hash  blockNumber  \
# 0  0xea6d13eb2e9ee57397a7e11fc809eb1b7dd0e648fa1f...     28072711
# 1  0xd0c79e92f86a971d6d4ff7604c030eb82a7eb85803a1...     28072711
# 2  0xc8c1403755684966fb5d9cae2d7faa3ed221c642ec05...     28072711
# 3  0xc3f4a0884c713e745f4ffe71d9ef6e2a3aefb7b9c84b...     28072711
# ...

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of                                                   id   timestamp  \
# 0  0xea6d13eb2e9ee57397a7e11fc809eb1b7dd0e648fa1f...  1742934769
# 1  0xd0c79e92f86a971d6d4ff7604c030eb82a7eb85803a1...  1742934769
# 2  0xc8c1403755684966fb5d9cae2d7faa3ed221c642ec05...  1742934769
# 3  0xc3f4a0884c713e745f4ffe71d9ef6e2a3aefb7b9c84b...  1742934769
# 4  0x956157768a793c13a44b7ef92e71241d8eba09d076b7...  1742934769
#
#     amountInUSD  amountOutUSD  \
# 0  3.050554e+01  3.040057e+01
# 1  1.152279e-09  1.140756e-09
# 2  1.152279e-09  0.000000e+00
# 3  1.420116e+01  1.405769e+01
# 4  3.522605e+01  3.522252e+01
#
#                                                 hash  blockNumber  \
# 0  0xea6d13eb2e9ee57397a7e11fc809eb1b7dd0e648fa1f...     28072711
# 1  0xd0c79e92f86a971d6d4ff7604c030eb82a7eb85803a1...     28072711
# 2  0xc8c1403755684966fb5d9cae2d7faa3ed221c642ec05...     28072711
# 3  0xc3f4a0884c713e745f4ffe71d9ef6e2a3aefb7b9c84b...     28072711
# ...

# %%
data.dropna()
# Out:
#                                                   id   timestamp  \
# 0  0xea6d13eb2e9ee57397a7e11fc809eb1b7dd0e648fa1f...  1742934769
# 1  0xd0c79e92f86a971d6d4ff7604c030eb82a7eb85803a1...  1742934769
# 2  0xc8c1403755684966fb5d9cae2d7faa3ed221c642ec05...  1742934769
# 3  0xc3f4a0884c713e745f4ffe71d9ef6e2a3aefb7b9c84b...  1742934769
# 4  0x956157768a793c13a44b7ef92e71241d8eba09d076b7...  1742934769
#
#     amountInUSD  amountOutUSD  \
# 0  3.050554e+01  3.040057e+01
# 1  1.152279e-09  1.140756e-09
# 2  1.152279e-09  0.000000e+00
# 3  1.420116e+01  1.405769e+01
# 4  3.522605e+01  3.522252e+01
#
#                                                 hash  blockNumber  \
# 0  0xea6d13eb2e9ee57397a7e11fc809eb1b7dd0e648fa1f...     28072711
# 1  0xd0c79e92f86a971d6d4ff7604c030eb82a7eb85803a1...     28072711
# 2  0xc8c1403755684966fb5d9cae2d7faa3ed221c642ec05...     28072711
# 3  0xc3f4a0884c713e745f4ffe71d9ef6e2a3aefb7b9c84b...     28072711
# ...

# %%
data.nunique()
# Out:
# id                          5
# timestamp                   1
# amountInUSD                 4
# amountOutUSD                5
# hash                        5
# blockNumber                 1
# pool__activeLiquidityUSD    1
# dtype: int64
